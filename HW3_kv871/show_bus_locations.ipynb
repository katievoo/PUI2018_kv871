# %%
#got help from christine and cyrus
#martha showed me how to convert to a py file and run that in my terminal


import pylab as pl
import pandas as pd
import os
import json
import sys
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
    
from __future__ import print_function

# %%
# %pylab inline
pl.rc ('font', size=15)
this_key= 'f7ec514a-23b0-4fc6-a89e-e9408bee9b6c'
this_bus='B44'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['var']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
url = 'http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=' + this_key + '&VehicleMonitoringDetailLevel=calls&LineRef=' + this_bus

#print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)

print (data.keys())
# Out:
# dict_keys(['Siri'])

# %%
(type(data))
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['Siri'])

# %%
url = 'http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=' + this_key + '&VehicleMonitoringDetailLevel=calls&LineRef=' + this_bus
print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=f7ec514a-23b0-4fc6-a89e-e9408bee9b6c&VehicleMonitoringDetailLevel=calls&LineRef=B44

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
# Out:
# [{'MonitoredVehicleJourney': {'Bearing': 109.48613,
#    'BlockRef': 'MTA NYCT_FB_D8-Weekday-SDon_E_FB_40380_B44-28',
#    'DestinationName': 'WILLAMSBURG BRIDGE PLZ via NOSTRAND',
#    'DestinationRef': 'MTA_901010',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FB_D8-Weekday-SDon-137400_B44_50'},
#    'JourneyPatternRef': 'MTA_B44O0498',
#    'LineRef': 'MTA NYCT_B44',
#    'Monitored': True,
#    'MonitoredCall': {'Extensions': {'Distances': {'CallDistanceAlongRoute': 9905.05,
#       'DistanceFromCall': 0.0,
#       'PresentableDistance': 'at stop',
#       'StopsFromCall': 0}},
#     'StopPointName': 'NEW YORK AV/EMPIRE BL',
#     'StopPointRef': 'MTA_303398',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'Extensions': {'Distances': {'CallDistanceAlongRoute': 9905.05,
#         'DistanceFromCall': 0.0,
#         'PresentableDistance': 'at stop',
#         'StopsFromCall': 0}},
#       'StopPointName': 'NEW YORK AV/EMPIRE BL',
#       'StopPointRef': 'MTA_303398'},
#      {'ExpectedArrivalTime': '2018-09-25T23:36:16.038-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10088.84,
#         'DistanceFromCall': 183.79,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'NEW YORK AV/MONTGOMERY ST',
#       'StopPointRef': 'MTA_303399'},
#      {'ExpectedArrivalTime': '2018-09-25T23:36:57.302-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10287.75,
#         'DistanceFromCall': 382.7,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'NEW YORK AV/CARROLL ST',
#       'StopPointRef': 'MTA_303400'},
#      {'ExpectedArrivalTime': '2018-09-25T23:37:39.410-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10480.24,
#         'DistanceFromCall': 575.19,
#         'PresentableDistance': '3 stops away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'NEW YORK AV/UNION ST',
#       'StopPointRef': 'MTA_303401'},
#      {'ExpectedArrivalTime': '2018-09-25T23:38:12.410-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10610.74,
#         'DistanceFromCall': 705.69,
#         'PresentableDistance': '4 stops away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'NEW YORK AV/EASTERN PY',
#       'StopPointRef': 'MTA_303402'},
#      {'ExpectedArrivalTime': '2018-09-25T23:38:38.864-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10732.86,
#         'DistanceFromCall': 827.81,
#         'PresentableDistance': '0.5 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'NEW YORK AV/ST JOHNS PL',
#       'StopPointRef': 'MTA_303403'},
#      {'ExpectedArrivalTime': '2018-09-25T23:39:17.297-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10883.93,
#         'DistanceFromCall': 978.88,
#         'PresentableDistance': '0.6 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'NEW YORK AV/STERLING PL',
#       'StopPointRef': 'MTA_303404'},
#      {'ExpectedArrivalTime': '2018-09-25T23:39:54.097-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11081.15,
#         'DistanceFromCall': 1176.1,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'NEW YORK AV/PROSPECT PL',
#       'StopPointRef': 'MTA_303405'},
#      {'ExpectedArrivalTime': '2018-09-25T23:40:30.719-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11234.61,
#         'DistanceFromCall': 1329.56,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'NEW YORK AV/BERGEN ST',
#       'StopPointRef': 'MTA_303406'},
#      {'ExpectedArrivalTime': '2018-09-25T23:41:12.779-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11455.53,
#         'DistanceFromCall': 1550.48,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'NEW YORK AV/PACIFIC ST',
#       'StopPointRef': 'MTA_303407'},
#      {'ExpectedArrivalTime': '2018-09-25T23:41:53.135-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11555.81,
#         'DistanceFromCall': 1650.76,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 10}},
#       'StopPointName': 'NEW YORK AV/ATLANTIC AV',
#       'StopPointRef': 'MTA_303408'},
#      {'ExpectedArrivalTime': '2018-09-25T23:43:00.034-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11768.13,
#         'DistanceFromCall': 1863.08,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 11}},
#       'StopPointName': 'FULTON ST/NEW YORK AV',
#       'StopPointRef': 'MTA_302414'},
#      {'ExpectedArrivalTime': '2018-09-25T23:44:04.234-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12022.83,
#         'DistanceFromCall': 2117.78,
#         'PresentableDistance': '1.3 miles away',
#         'StopsFromCall': 12}},
#       'StopPointName': 'FULTON ST/NOSTRAND AV',
#       'StopPointRef': 'MTA_302415'},
#      {'ExpectedArrivalTime': '2018-09-25T23:45:33.434-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12331.69,
#         'DistanceFromCall': 2426.64,
#         'PresentableDistance': '1.5 miles away',
#         'StopsFromCall': 13}},
#       'StopPointName': 'BEDFORD AV/FULTON ST',
#       'StopPointRef': 'MTA_303411'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:01.978-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12490.3,
#         'DistanceFromCall': 2585.25,
#         'PresentableDistance': '1.6 miles away',
#         'StopsFromCall': 14}},
#       'StopPointName': 'BEDFORD AV/HANCOCK ST',
#       'StopPointRef': 'MTA_303412'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:19.231-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12605.53,
#         'DistanceFromCall': 2700.48,
#         'PresentableDistance': '1.7 miles away',
#         'StopsFromCall': 15}},
#       'StopPointName': 'BEDFORD AV/PUTNAM AV',
#       'StopPointRef': 'MTA_303413'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:53.431-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12834.34,
#         'DistanceFromCall': 2929.29,
#         'PresentableDistance': '1.8 miles away',
#         'StopsFromCall': 16}},
#       'StopPointName': 'BEDFORD AV/GATES AV',
#       'StopPointRef': 'MTA_801163'},
#      {'ExpectedArrivalTime': '2018-09-25T23:48:03.533-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13148.75,
#         'DistanceFromCall': 3243.7,
#         'PresentableDistance': '2.0 miles away',
#         'StopsFromCall': 17}},
#       'StopPointName': 'BEDFORD AV/GREENE AV',
#       'StopPointRef': 'MTA_303416'},
#      {'ExpectedArrivalTime': '2018-09-25T23:48:28.555-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13266.48,
#         'DistanceFromCall': 3361.43,
#         'PresentableDistance': '2.1 miles away',
#         'StopsFromCall': 18}},
#       'StopPointName': 'BEDFORD AV/LAFAYETTE AV',
#       'StopPointRef': 'MTA_303417'},
#      {'ExpectedArrivalTime': '2018-09-25T23:49:12.561-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13484.39,
#         'DistanceFromCall': 3579.34,
#         'PresentableDistance': '2.2 miles away',
#         'StopsFromCall': 19}},
#       'StopPointName': 'BEDFORD AV/DE KALB AV',
#       'StopPointRef': 'MTA_303418'},
#      {'ExpectedArrivalTime': '2018-09-25T23:49:47.658-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13718.76,
#         'DistanceFromCall': 3813.71,
#         'PresentableDistance': '2.4 miles away',
#         'StopsFromCall': 20}},
#       'StopPointName': 'BEDFORD AV/WILLOUGHBY AV',
#       'StopPointRef': 'MTA_303419'},
#      {'ExpectedArrivalTime': '2018-09-25T23:50:09.029-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13842.6,
#         'DistanceFromCall': 3937.55,
#         'PresentableDistance': '2.4 miles away',
#         'StopsFromCall': 21}},
#       'StopPointName': 'BEDFORD AV/MYRTLE AV',
#       'StopPointRef': 'MTA_303420'},
#      {'ExpectedArrivalTime': '2018-09-25T23:51:06.697-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14090.52,
#         'DistanceFromCall': 4185.47,
#         'PresentableDistance': '2.6 miles away',
#         'StopsFromCall': 22}},
#       'StopPointName': 'BEDFORD AV/PARK AV',
#       'StopPointRef': 'MTA_303421'},
#      {'ExpectedArrivalTime': '2018-09-25T23:51:44.455-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14338.73,
#         'DistanceFromCall': 4433.68,
#         'PresentableDistance': '2.8 miles away',
#         'StopsFromCall': 23}},
#       'StopPointName': 'BEDFORD AV/FLUSHING AV',
#       'StopPointRef': 'MTA_303422'},
#      {'ExpectedArrivalTime': '2018-09-25T23:53:26.684-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14847.53,
#         'DistanceFromCall': 4942.48,
#         'PresentableDistance': '3.1 miles away',
#         'StopsFromCall': 24}},
#       'StopPointName': 'BEDFORD AV/HEWES ST',
#       'StopPointRef': 'MTA_303425'},
#      {'ExpectedArrivalTime': '2018-09-25T23:54:59.084-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15281.34,
#         'DistanceFromCall': 5376.29,
#         'PresentableDistance': '3.3 miles away',
#         'StopsFromCall': 25}},
#       'StopPointName': 'BEDFORD AV/TAYLOR ST',
#       'StopPointRef': 'MTA_303427'},
#      {'ExpectedArrivalTime': '2018-09-25T23:57:04.054-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15891.79,
#         'DistanceFromCall': 5986.74,
#         'PresentableDistance': '3.7 miles away',
#         'StopsFromCall': 26}},
#       'StopPointName': 'WASHINGTON PLZ/WASHINGTON PLZ',
#       'StopPointRef': 'MTA_901010'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_300351',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B44',
#    'SituationRef': [{'SituationSimpleRef': 'MTA NYCT_194883'}],
#    'VehicleLocation': {'Latitude': 40.663916, 'Longitude': -73.948082},
#    'VehicleRef': 'MTA NYCT_5043'},
#   'RecordedAtTime': '2018-09-25T23:35:28.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 340.18686,
#    'BlockRef': 'MTA NYCT_FB_D8-Weekday-SDon_E_FB_41160_B44-19',
#    'DestinationName': 'WILLAMSBURG BRIDGE PLZ via NOSTRAND',
#    'DestinationRef': 'MTA_901010',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FB_D8-Weekday-SDon-136100_B44_43'},
#    'JourneyPatternRef': 'MTA_B44O0498',
#    'LineRef': 'MTA NYCT_B44',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-25T23:35:50.825-04:00',
#     'ExpectedDepartureTime': '2018-09-25T23:35:50.825-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 15891.79,
#       'DistanceFromCall': 5.17,
#       'PresentableDistance': 'at stop',
#       'StopsFromCall': 0}},
#     'StopPointName': 'WASHINGTON PLZ/WASHINGTON PLZ',
#     'StopPointRef': 'MTA_901010',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T23:35:49.825-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15891.79,
#         'DistanceFromCall': 5.17,
#         'PresentableDistance': 'at stop',
#         'StopsFromCall': 0}},
#       'StopPointName': 'WASHINGTON PLZ/WASHINGTON PLZ',
#       'StopPointRef': 'MTA_901010'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_300351',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B44',
#    'SituationRef': [{'SituationSimpleRef': 'MTA NYCT_194883'}],
#    'VehicleLocation': {'Latitude': 40.709361, 'Longitude': -73.95966},
#    'VehicleRef': 'MTA NYCT_4243'},
#   'RecordedAtTime': '2018-09-25T23:35:20.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 100.88553,
#    'BlockRef': 'MTA NYCT_FB_D8-Weekday-SDon_E_FB_19440_B44-10',
#    'DestinationName': 'WILLAMSBURG BRIDGE PLZ via NOSTRAND',
#    'DestinationRef': 'MTA_901010',
#    'DirectionRef': '0',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FB_D8-Weekday-SDon-140300_B44_49'},
#    'JourneyPatternRef': 'MTA_B44O0493',
#    'LineRef': 'MTA NYCT_B44',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-25T23:35:50.825-04:00',
#     'ExpectedDepartureTime': '2018-09-25T23:35:50.825-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 2963.96,
#       'DistanceFromCall': 11.63,
#       'PresentableDistance': 'at stop',
#       'StopsFromCall': 0}},
#     'StopPointName': 'NOSTRAND AV/QUENTIN RD',
#     'StopPointRef': 'MTA_303370',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T23:35:49.825-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2963.96,
#         'DistanceFromCall': 11.63,
#         'PresentableDistance': 'at stop',
#         'StopsFromCall': 0}},
#       'StopPointName': 'NOSTRAND AV/QUENTIN RD',
#       'StopPointRef': 'MTA_303370'},
#      {'ExpectedArrivalTime': '2018-09-25T23:36:30.213-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3299.22,
#         'DistanceFromCall': 346.89,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'NOSTRAND AV/AV P',
#       'StopPointRef': 'MTA_303371'},
#      {'ExpectedArrivalTime': '2018-09-25T23:36:47.681-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3448.61,
#         'DistanceFromCall': 496.28,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'NOSTRAND AV/MARINE PY',
#       'StopPointRef': 'MTA_303372'},
#      {'ExpectedArrivalTime': '2018-09-25T23:37:11.104-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3602.51,
#         'DistanceFromCall': 650.18,
#         'PresentableDistance': '3 stops away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'NOSTRAND AV/KINGS HY',
#       'StopPointRef': 'MTA_307127'},
#      {'ExpectedArrivalTime': '2018-09-25T23:37:47.688-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3796.61,
#         'DistanceFromCall': 844.28,
#         'PresentableDistance': '0.5 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'NOSTRAND AV/AV N',
#       'StopPointRef': 'MTA_303374'},
#      {'ExpectedArrivalTime': '2018-09-25T23:38:21.523-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4063.96,
#         'DistanceFromCall': 1111.62,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'NOSTRAND AV/AV M',
#       'StopPointRef': 'MTA_303375'},
#      {'ExpectedArrivalTime': '2018-09-25T23:38:51.748-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4284.71,
#         'DistanceFromCall': 1332.37,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'NOSTRAND AV/AV L',
#       'StopPointRef': 'MTA_303376'},
#      {'ExpectedArrivalTime': '2018-09-25T23:39:45.264-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4582.57,
#         'DistanceFromCall': 1630.23,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'NOSTRAND AV/AV K',
#       'StopPointRef': 'MTA_303377'},
#      {'ExpectedArrivalTime': '2018-09-25T23:40:32.113-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4873.24,
#         'DistanceFromCall': 1920.91,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'NOSTRAND AV/AV J',
#       'StopPointRef': 'MTA_303378'},
#      {'ExpectedArrivalTime': '2018-09-25T23:41:19.932-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5139.48,
#         'DistanceFromCall': 2187.14,
#         'PresentableDistance': '1.4 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'NOSTRAND AV/AV I',
#       'StopPointRef': 'MTA_303379'},
#      {'ExpectedArrivalTime': '2018-09-25T23:42:21.932-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5458.89,
#         'DistanceFromCall': 2506.56,
#         'PresentableDistance': '1.6 miles away',
#         'StopsFromCall': 10}},
#       'StopPointName': 'NOSTRAND AV/FLATBUSH AV',
#       'StopPointRef': 'MTA_303380'},
#      {'ExpectedArrivalTime': '2018-09-25T23:44:05.729-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5677.96,
#         'DistanceFromCall': 2725.62,
#         'PresentableDistance': '1.7 miles away',
#         'StopsFromCall': 11}},
#       'StopPointName': 'NOSTRAND AV/GLENWOOD RD',
#       'StopPointRef': 'MTA_303381'},
#      {'ExpectedArrivalTime': '2018-09-25T23:45:11.850-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5929.18,
#         'DistanceFromCall': 2976.84,
#         'PresentableDistance': '1.8 miles away',
#         'StopsFromCall': 12}},
#       'StopPointName': 'FARRAGUT RD/NOSTRAND AV',
#       'StopPointRef': 'MTA_303382'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:17.850-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6182.49,
#         'DistanceFromCall': 3230.15,
#         'PresentableDistance': '2.0 miles away',
#         'StopsFromCall': 13}},
#       'StopPointName': 'NEW YORK AV/FARRAGUT RD',
#       'StopPointRef': 'MTA_303383'},
#      {'ExpectedArrivalTime': '2018-09-25T23:47:22.304-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6440.03,
#         'DistanceFromCall': 3487.69,
#         'PresentableDistance': '2.2 miles away',
#         'StopsFromCall': 14}},
#       'StopPointName': 'NEW YORK AV/FOSTER AV',
#       'StopPointRef': 'MTA_303384'},
#      {'ExpectedArrivalTime': '2018-09-25T23:48:25.304-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6648.9,
#         'DistanceFromCall': 3696.56,
#         'PresentableDistance': '2.3 miles away',
#         'StopsFromCall': 15}},
#       'StopPointName': 'NEW YORK AV/AV D',
#       'StopPointRef': 'MTA_303385'},
#      {'ExpectedArrivalTime': '2018-09-25T23:49:31.230-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6955.56,
#         'DistanceFromCall': 4003.22,
#         'PresentableDistance': '2.5 miles away',
#         'StopsFromCall': 16}},
#       'StopPointName': 'NEW YORK AV/CLARENDON RD',
#       'StopPointRef': 'MTA_303386'},
#      {'ExpectedArrivalTime': '2018-09-25T23:50:25.753-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7164.4,
#         'DistanceFromCall': 4212.07,
#         'PresentableDistance': '2.6 miles away',
#         'StopsFromCall': 17}},
#       'StopPointName': 'NEW YORK AV/BEVERLY RD',
#       'StopPointRef': 'MTA_303387'},
#      {'ExpectedArrivalTime': '2018-09-25T23:51:03.442-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7351.47,
#         'DistanceFromCall': 4399.13,
#         'PresentableDistance': '2.7 miles away',
#         'StopsFromCall': 18}},
#       'StopPointName': 'NEW YORK AV/TILDEN AV',
#       'StopPointRef': 'MTA_303388'},
#      {'ExpectedArrivalTime': '2018-09-25T23:51:58.028-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7584.77,
#         'DistanceFromCall': 4632.43,
#         'PresentableDistance': '2.9 miles away',
#         'StopsFromCall': 19}},
#       'StopPointName': 'NEW YORK AV/SNYDER AV',
#       'StopPointRef': 'MTA_303389'},
#      {'ExpectedArrivalTime': '2018-09-25T23:52:53.538-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7792.19,
#         'DistanceFromCall': 4839.86,
#         'PresentableDistance': '3.0 miles away',
#         'StopsFromCall': 20}},
#       'StopPointName': 'NEW YORK AV/CHURCH AV',
#       'StopPointRef': 'MTA_303390'},
#      {'ExpectedArrivalTime': '2018-09-25T23:54:00.064-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7999.55,
#         'DistanceFromCall': 5047.21,
#         'PresentableDistance': '3.1 miles away',
#         'StopsFromCall': 21}},
#       'StopPointName': 'NEW YORK AV/LINDEN BL',
#       'StopPointRef': 'MTA_303391'},
#      {'ExpectedArrivalTime': '2018-09-25T23:54:36.496-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8169.01,
#         'DistanceFromCall': 5216.68,
#         'PresentableDistance': '3.2 miles away',
#         'StopsFromCall': 22}},
#       'StopPointName': 'NEW YORK AV/LENOX RD',
#       'StopPointRef': 'MTA_303392'},
#      {'ExpectedArrivalTime': '2018-09-25T23:55:15.711-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8309.64,
#         'DistanceFromCall': 5357.3,
#         'PresentableDistance': '3.3 miles away',
#         'StopsFromCall': 23}},
#       'StopPointName': 'NEW YORK AV/CLARKSON AV',
#       'StopPointRef': 'MTA_303393'},
#      {'ExpectedArrivalTime': '2018-09-25T23:56:13.223-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8496.52,
#         'DistanceFromCall': 5544.19,
#         'PresentableDistance': '3.4 miles away',
#         'StopsFromCall': 24}},
#       'StopPointName': 'NEW YORK AV/WINTHROP ST',
#       'StopPointRef': 'MTA_303394'},
#      {'ExpectedArrivalTime': '2018-09-25T23:56:53.787-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8674.79,
#         'DistanceFromCall': 5722.45,
#         'PresentableDistance': '3.6 miles away',
#         'StopsFromCall': 25}},
#       'StopPointName': 'NEW YORK AV/FENIMORE ST',
#       'StopPointRef': 'MTA_303395'},
#      {'ExpectedArrivalTime': '2018-09-25T23:57:19.212-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8790.83,
#         'DistanceFromCall': 5838.49,
#         'PresentableDistance': '3.6 miles away',
#         'StopsFromCall': 26}},
#       'StopPointName': 'NEW YORK AV/MIDWOOD ST',
#       'StopPointRef': 'MTA_303396'},
#      {'ExpectedArrivalTime': '2018-09-25T23:58:03.087-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8996.55,
#         'DistanceFromCall': 6044.21,
#         'PresentableDistance': '3.8 miles away',
#         'StopsFromCall': 27}},
#       'StopPointName': 'NEW YORK AV/EAST NEW YORK AV',
#       'StopPointRef': 'MTA_306624'},
#      {'ExpectedArrivalTime': '2018-09-25T23:58:46.166-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9204.06,
#         'DistanceFromCall': 6251.73,
#         'PresentableDistance': '3.9 miles away',
#         'StopsFromCall': 28}},
#       'StopPointName': 'NEW YORK AV/EMPIRE BL',
#       'StopPointRef': 'MTA_303398'},
#      {'ExpectedArrivalTime': '2018-09-25T23:59:34.205-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9387.85,
#         'DistanceFromCall': 6435.52,
#         'PresentableDistance': '4.0 miles away',
#         'StopsFromCall': 29}},
#       'StopPointName': 'NEW YORK AV/MONTGOMERY ST',
#       'StopPointRef': 'MTA_303399'},
#      {'ExpectedArrivalTime': '2018-09-26T00:00:15.469-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9586.76,
#         'DistanceFromCall': 6634.43,
#         'PresentableDistance': '4.1 miles away',
#         'StopsFromCall': 30}},
#       'StopPointName': 'NEW YORK AV/CARROLL ST',
#       'StopPointRef': 'MTA_303400'},
#      {'ExpectedArrivalTime': '2018-09-26T00:00:57.577-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9779.26,
#         'DistanceFromCall': 6826.92,
#         'PresentableDistance': '4.2 miles away',
#         'StopsFromCall': 31}},
#       'StopPointName': 'NEW YORK AV/UNION ST',
#       'StopPointRef': 'MTA_303401'},
#      {'ExpectedArrivalTime': '2018-09-26T00:01:30.577-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9909.75,
#         'DistanceFromCall': 6957.42,
#         'PresentableDistance': '4.3 miles away',
#         'StopsFromCall': 32}},
#       'StopPointName': 'NEW YORK AV/EASTERN PY',
#       'StopPointRef': 'MTA_303402'},
#      {'ExpectedArrivalTime': '2018-09-26T00:01:57.031-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10031.87,
#         'DistanceFromCall': 7079.54,
#         'PresentableDistance': '4.4 miles away',
#         'StopsFromCall': 33}},
#       'StopPointName': 'NEW YORK AV/ST JOHNS PL',
#       'StopPointRef': 'MTA_303403'},
#      {'ExpectedArrivalTime': '2018-09-26T00:02:35.464-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10182.94,
#         'DistanceFromCall': 7230.6,
#         'PresentableDistance': '4.5 miles away',
#         'StopsFromCall': 34}},
#       'StopPointName': 'NEW YORK AV/STERLING PL',
#       'StopPointRef': 'MTA_303404'},
#      {'ExpectedArrivalTime': '2018-09-26T00:03:12.264-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10380.16,
#         'DistanceFromCall': 7427.83,
#         'PresentableDistance': '4.6 miles away',
#         'StopsFromCall': 35}},
#       'StopPointName': 'NEW YORK AV/PROSPECT PL',
#       'StopPointRef': 'MTA_303405'},
#      {'ExpectedArrivalTime': '2018-09-26T00:03:48.886-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10533.63,
#         'DistanceFromCall': 7581.29,
#         'PresentableDistance': '4.7 miles away',
#         'StopsFromCall': 36}},
#       'StopPointName': 'NEW YORK AV/BERGEN ST',
#       'StopPointRef': 'MTA_303406'},
#      {'ExpectedArrivalTime': '2018-09-26T00:04:30.946-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10754.55,
#         'DistanceFromCall': 7802.21,
#         'PresentableDistance': '4.8 miles away',
#         'StopsFromCall': 37}},
#       'StopPointName': 'NEW YORK AV/PACIFIC ST',
#       'StopPointRef': 'MTA_303407'},
#      {'ExpectedArrivalTime': '2018-09-26T00:05:11.302-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10854.82,
#         'DistanceFromCall': 7902.49,
#         'PresentableDistance': '4.9 miles away',
#         'StopsFromCall': 38}},
#       'StopPointName': 'NEW YORK AV/ATLANTIC AV',
#       'StopPointRef': 'MTA_303408'},
#      {'ExpectedArrivalTime': '2018-09-26T00:06:18.201-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11067.15,
#         'DistanceFromCall': 8114.81,
#         'PresentableDistance': '5.0 miles away',
#         'StopsFromCall': 39}},
#       'StopPointName': 'FULTON ST/NEW YORK AV',
#       'StopPointRef': 'MTA_302414'},
#      {'ExpectedArrivalTime': '2018-09-26T00:07:22.401-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11321.84,
#         'DistanceFromCall': 8369.51,
#         'PresentableDistance': '5.2 miles away',
#         'StopsFromCall': 40}},
#       'StopPointName': 'FULTON ST/NOSTRAND AV',
#       'StopPointRef': 'MTA_302415'},
#      {'ExpectedArrivalTime': '2018-09-26T00:08:50.001-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11630.7,
#         'DistanceFromCall': 8678.37,
#         'PresentableDistance': '5.4 miles away',
#         'StopsFromCall': 41}},
#       'StopPointName': 'BEDFORD AV/FULTON ST',
#       'StopPointRef': 'MTA_303411'},
#      {'ExpectedArrivalTime': '2018-09-26T00:09:17.745-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11789.32,
#         'DistanceFromCall': 8836.98,
#         'PresentableDistance': '5.5 miles away',
#         'StopsFromCall': 42}},
#       'StopPointName': 'BEDFORD AV/HANCOCK ST',
#       'StopPointRef': 'MTA_303412'},
#      {'ExpectedArrivalTime': '2018-09-26T00:09:34.398-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11904.55,
#         'DistanceFromCall': 8952.21,
#         'PresentableDistance': '5.6 miles away',
#         'StopsFromCall': 43}},
#       'StopPointName': 'BEDFORD AV/PUTNAM AV',
#       'StopPointRef': 'MTA_303413'},
#      {'ExpectedArrivalTime': '2018-09-26T00:10:07.398-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12133.35,
#         'DistanceFromCall': 9181.02,
#         'PresentableDistance': '5.7 miles away',
#         'StopsFromCall': 44}},
#       'StopPointName': 'BEDFORD AV/GATES AV',
#       'StopPointRef': 'MTA_801163'},
#      {'ExpectedArrivalTime': '2018-09-26T00:11:15.900-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12447.76,
#         'DistanceFromCall': 9495.43,
#         'PresentableDistance': '5.9 miles away',
#         'StopsFromCall': 45}},
#       'StopPointName': 'BEDFORD AV/GREENE AV',
#       'StopPointRef': 'MTA_303416'},
#      {'ExpectedArrivalTime': '2018-09-26T00:11:40.322-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12565.5,
#         'DistanceFromCall': 9613.16,
#         'PresentableDistance': '6.0 miles away',
#         'StopsFromCall': 46}},
#       'StopPointName': 'BEDFORD AV/LAFAYETTE AV',
#       'StopPointRef': 'MTA_303417'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:23.128-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12783.41,
#         'DistanceFromCall': 9831.07,
#         'PresentableDistance': '6.1 miles away',
#         'StopsFromCall': 47}},
#       'StopPointName': 'BEDFORD AV/DE KALB AV',
#       'StopPointRef': 'MTA_303418'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:57.025-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13017.77,
#         'DistanceFromCall': 10065.43,
#         'PresentableDistance': '6.3 miles away',
#         'StopsFromCall': 48}},
#       'StopPointName': 'BEDFORD AV/WILLOUGHBY AV',
#       'StopPointRef': 'MTA_303419'},
#      {'ExpectedArrivalTime': '2018-09-26T00:13:17.796-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13141.62,
#         'DistanceFromCall': 10189.28,
#         'PresentableDistance': '6.3 miles away',
#         'StopsFromCall': 49}},
#       'StopPointName': 'BEDFORD AV/MYRTLE AV',
#       'StopPointRef': 'MTA_303420'},
#      {'ExpectedArrivalTime': '2018-09-26T00:14:14.064-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13389.54,
#         'DistanceFromCall': 10437.2,
#         'PresentableDistance': '6.5 miles away',
#         'StopsFromCall': 50}},
#       'StopPointName': 'BEDFORD AV/PARK AV',
#       'StopPointRef': 'MTA_303421'},
#      {'ExpectedArrivalTime': '2018-09-26T00:14:50.622-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13637.75,
#         'DistanceFromCall': 10685.41,
#         'PresentableDistance': '6.6 miles away',
#         'StopsFromCall': 51}},
#       'StopPointName': 'BEDFORD AV/FLUSHING AV',
#       'StopPointRef': 'MTA_303422'},
#      {'ExpectedArrivalTime': '2018-09-26T00:16:32.851-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14146.55,
#         'DistanceFromCall': 11194.21,
#         'PresentableDistance': '7.0 miles away',
#         'StopsFromCall': 52}},
#       'StopPointName': 'BEDFORD AV/HEWES ST',
#       'StopPointRef': 'MTA_303425'},
#      {'ExpectedArrivalTime': '2018-09-26T00:18:05.251-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14580.35,
#         'DistanceFromCall': 11628.02,
#         'PresentableDistance': '7.2 miles away',
#         'StopsFromCall': 53}},
#       'StopPointName': 'BEDFORD AV/TAYLOR ST',
#       'StopPointRef': 'MTA_303427'},
#      {'ExpectedArrivalTime': '2018-09-26T00:20:10.221-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15190.81,
#         'DistanceFromCall': 12238.47,
#         'PresentableDistance': '7.6 miles away',
#         'StopsFromCall': 54}},
#       'StopPointName': 'WASHINGTON PLZ/WASHINGTON PLZ',
#       'StopPointRef': 'MTA_901010'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_307020',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B44',
#    'SituationRef': [{'SituationSimpleRef': 'MTA NYCT_194883'}],
#    'VehicleLocation': {'Latitude': 40.61001, 'Longitude': -73.943673},
#    'VehicleRef': 'MTA NYCT_5144'},
#   'RecordedAtTime': '2018-09-25T23:35:35.000-04:00'},
#  {'MonitoredVehicleJourney': {'Bearing': 232.12502,
#    'BlockRef': 'MTA NYCT_FB_D8-Weekday-SDon_E_FB_23760_B44-22',
#    'DestinationName': 'EMMONS AV',
#    'DestinationRef': 'MTA_901009',
#    'DirectionRef': '1',
#    'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25',
#     'DatedVehicleJourneyRef': 'MTA NYCT_FB_D8-Weekday-SDon-141200_B44_46'},
#    'JourneyPatternRef': 'MTA_B44O0452',
#    'LineRef': 'MTA NYCT_B44',
#    'Monitored': True,
#    'MonitoredCall': {'ExpectedArrivalTime': '2018-09-25T23:35:50.825-04:00',
#     'ExpectedDepartureTime': '2018-09-25T23:35:50.825-04:00',
#     'Extensions': {'Distances': {'CallDistanceAlongRoute': 468.57,
#       'DistanceFromCall': 16.35,
#       'PresentableDistance': 'at stop',
#       'StopsFromCall': 0}},
#     'StopPointName': 'LEE AV/TAYLOR ST',
#     'StopPointRef': 'MTA_350218',
#     'VisitNumber': 1},
#    'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T23:35:49.825-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 468.57,
#         'DistanceFromCall': 16.35,
#         'PresentableDistance': 'at stop',
#         'StopsFromCall': 0}},
#       'StopPointName': 'LEE AV/TAYLOR ST',
#       'StopPointRef': 'MTA_350218'},
#      {'ExpectedArrivalTime': '2018-09-25T23:38:12.447-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 972.11,
#         'DistanceFromCall': 519.88,
#         'PresentableDistance': '1 stop away',
#         'StopsFromCall': 1}},
#       'StopPointName': 'LEE AV/HEWES ST',
#       'StopPointRef': 'MTA_303513'},
#      {'ExpectedArrivalTime': '2018-09-25T23:40:20.395-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 1519.52,
#         'DistanceFromCall': 1067.29,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'LEE AV/FLUSHING AV',
#       'StopPointRef': 'MTA_303441'},
#      {'ExpectedArrivalTime': '2018-09-25T23:41:28.381-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 1817.27,
#         'DistanceFromCall': 1365.04,
#         'PresentableDistance': '0.8 miles away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'NOSTRAND AV/PARK AV',
#       'StopPointRef': 'MTA_308354'},
#      {'ExpectedArrivalTime': '2018-09-25T23:42:12.656-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2075.01,
#         'DistanceFromCall': 1622.78,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'NOSTRAND AV/MYRTLE AV',
#       'StopPointRef': 'MTA_303444'},
#      {'ExpectedArrivalTime': '2018-09-25T23:42:58.023-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2244.38,
#         'DistanceFromCall': 1792.16,
#         'PresentableDistance': '1.1 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'NOSTRAND AV/WILLOUGHBY AV',
#       'StopPointRef': 'MTA_303445'},
#      {'ExpectedArrivalTime': '2018-09-25T23:43:29.044-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2431.37,
#         'DistanceFromCall': 1979.15,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'NOSTRAND AV/DE KALB AV',
#       'StopPointRef': 'MTA_303446'},
#      {'ExpectedArrivalTime': '2018-09-25T23:44:32.255-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2643.01,
#         'DistanceFromCall': 2190.79,
#         'PresentableDistance': '1.4 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'NOSTRAND AV/LAFAYETTE AV',
#       'StopPointRef': 'MTA_303447'},
#      {'ExpectedArrivalTime': '2018-09-25T23:45:11.207-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 2809.21,
#         'DistanceFromCall': 2356.99,
#         'PresentableDistance': '1.5 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'NOSTRAND AV/GREENE AV',
#       'StopPointRef': 'MTA_303448'},
#      {'ExpectedArrivalTime': '2018-09-25T23:45:51.783-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3055.67,
#         'DistanceFromCall': 2603.44,
#         'PresentableDistance': '1.6 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'NOSTRAND AV/GATES AV',
#       'StopPointRef': 'MTA_307905'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:52.580-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3302.59,
#         'DistanceFromCall': 2850.37,
#         'PresentableDistance': '1.8 miles away',
#         'StopsFromCall': 10}},
#       'StopPointName': 'NOSTRAND AV/PUTNAM AV',
#       'StopPointRef': 'MTA_303451'},
#      {'ExpectedArrivalTime': '2018-09-25T23:47:24.032-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3467.29,
#         'DistanceFromCall': 3015.06,
#         'PresentableDistance': '1.9 miles away',
#         'StopsFromCall': 11}},
#       'StopPointName': 'NOSTRAND AV/HANCOCK ST',
#       'StopPointRef': 'MTA_302463'},
#      {'ExpectedArrivalTime': '2018-09-25T23:48:23.550-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 3720.13,
#         'DistanceFromCall': 3267.9,
#         'PresentableDistance': '2.0 miles away',
#         'StopsFromCall': 12}},
#       'StopPointName': 'NOSTRAND AV/FULTON ST',
#       'StopPointRef': 'MTA_308435'},
#      {'ExpectedArrivalTime': '2018-09-25T23:50:26.723-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4014.11,
#         'DistanceFromCall': 3561.88,
#         'PresentableDistance': '2.2 miles away',
#         'StopsFromCall': 13}},
#       'StopPointName': 'NOSTRAND AV/PACIFIC ST',
#       'StopPointRef': 'MTA_303456'},
#      {'ExpectedArrivalTime': '2018-09-25T23:51:34.950-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4199.62,
#         'DistanceFromCall': 3747.39,
#         'PresentableDistance': '2.3 miles away',
#         'StopsFromCall': 14}},
#       'StopPointName': 'NOSTRAND AV/BERGEN ST',
#       'StopPointRef': 'MTA_303457'},
#      {'ExpectedArrivalTime': '2018-09-25T23:52:34.150-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4339.72,
#         'DistanceFromCall': 3887.49,
#         'PresentableDistance': '2.4 miles away',
#         'StopsFromCall': 15}},
#       'StopPointName': 'NOSTRAND AV/PROSPECT PL',
#       'StopPointRef': 'MTA_308524'},
#      {'ExpectedArrivalTime': '2018-09-25T23:54:26.560-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4734.56,
#         'DistanceFromCall': 4282.33,
#         'PresentableDistance': '2.7 miles away',
#         'StopsFromCall': 16}},
#       'StopPointName': 'NOSTRAND AV/ST JOHNS PL',
#       'StopPointRef': 'MTA_303459'},
#      {'ExpectedArrivalTime': '2018-09-25T23:55:49.354-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4911.09,
#         'DistanceFromCall': 4458.86,
#         'PresentableDistance': '2.8 miles away',
#         'StopsFromCall': 17}},
#       'StopPointName': 'NOSTRAND AV/EASTERN PY',
#       'StopPointRef': 'MTA_303460'},
#      {'ExpectedArrivalTime': '2018-09-25T23:57:19.554-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5181.08,
#         'DistanceFromCall': 4728.85,
#         'PresentableDistance': '2.9 miles away',
#         'StopsFromCall': 18}},
#       'StopPointName': 'NOSTRAND AV/CARROLL ST',
#       'StopPointRef': 'MTA_303461'},
#      {'ExpectedArrivalTime': '2018-09-25T23:57:50.478-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5337.97,
#         'DistanceFromCall': 4885.74,
#         'PresentableDistance': '3.0 miles away',
#         'StopsFromCall': 19}},
#       'StopPointName': 'NOSTRAND AV/MONTGOMERY ST',
#       'StopPointRef': 'MTA_308443'},
#      {'ExpectedArrivalTime': '2018-09-25T23:58:43.161-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5558.64,
#         'DistanceFromCall': 5106.41,
#         'PresentableDistance': '3.2 miles away',
#         'StopsFromCall': 20}},
#       'StopPointName': 'NOSTRAND AV/EMPIRE BL',
#       'StopPointRef': 'MTA_303463'},
#      {'ExpectedArrivalTime': '2018-09-25T23:59:42.361-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5725.22,
#         'DistanceFromCall': 5272.99,
#         'PresentableDistance': '3.3 miles away',
#         'StopsFromCall': 21}},
#       'StopPointName': 'NOSTRAND AV/LEFFERTS AV',
#       'StopPointRef': 'MTA_303464'},
#      {'ExpectedArrivalTime': '2018-09-26T00:00:16.361-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5888.23,
#         'DistanceFromCall': 5436.0,
#         'PresentableDistance': '3.4 miles away',
#         'StopsFromCall': 22}},
#       'StopPointName': 'NOSTRAND AV/MAPLE ST',
#       'StopPointRef': 'MTA_303465'},
#      {'ExpectedArrivalTime': '2018-09-26T00:00:53.032-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6051.49,
#         'DistanceFromCall': 5599.26,
#         'PresentableDistance': '3.5 miles away',
#         'StopsFromCall': 23}},
#       'StopPointName': 'NOSTRAND AV/RUTLAND RD',
#       'StopPointRef': 'MTA_303466'},
#      {'ExpectedArrivalTime': '2018-09-26T00:01:31.534-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6225.72,
#         'DistanceFromCall': 5773.5,
#         'PresentableDistance': '3.6 miles away',
#         'StopsFromCall': 24}},
#       'StopPointName': 'NOSTRAND AV/HAWTHORNE ST',
#       'StopPointRef': 'MTA_303467'},
#      {'ExpectedArrivalTime': '2018-09-26T00:02:51.745-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6502.78,
#         'DistanceFromCall': 6050.55,
#         'PresentableDistance': '3.8 miles away',
#         'StopsFromCall': 25}},
#       'StopPointName': 'NOSTRAND AV/CLARKSON AV',
#       'StopPointRef': 'MTA_303469'},
#      {'ExpectedArrivalTime': '2018-09-26T00:04:23.764-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6808.04,
#         'DistanceFromCall': 6355.81,
#         'PresentableDistance': '3.9 miles away',
#         'StopsFromCall': 26}},
#       'StopPointName': 'NOSTRAND AV/LINDEN BL',
#       'StopPointRef': 'MTA_303471'},
#      {'ExpectedArrivalTime': '2018-09-26T00:05:31.436-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7021.44,
#         'DistanceFromCall': 6569.22,
#         'PresentableDistance': '4.1 miles away',
#         'StopsFromCall': 27}},
#       'StopPointName': 'NOSTRAND AV/CHURCH AV',
#       'StopPointRef': 'MTA_307737'},
#      {'ExpectedArrivalTime': '2018-09-26T00:06:36.387-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7216.96,
#         'DistanceFromCall': 6764.73,
#         'PresentableDistance': '4.2 miles away',
#         'StopsFromCall': 28}},
#       'StopPointName': 'NOSTRAND AV/SNYDER AV',
#       'StopPointRef': 'MTA_303473'},
#      {'ExpectedArrivalTime': '2018-09-26T00:07:14.804-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7445.74,
#         'DistanceFromCall': 6993.51,
#         'PresentableDistance': '4.3 miles away',
#         'StopsFromCall': 29}},
#       'StopPointName': 'NOSTRAND AV/TILDEN AV',
#       'StopPointRef': 'MTA_303474'},
#      {'ExpectedArrivalTime': '2018-09-26T00:08:09.226-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7642.29,
#         'DistanceFromCall': 7190.06,
#         'PresentableDistance': '4.5 miles away',
#         'StopsFromCall': 30}},
#       'StopPointName': 'NOSTRAND AV/BEVERLY RD',
#       'StopPointRef': 'MTA_303475'},
#      {'ExpectedArrivalTime': '2018-09-26T00:09:03.068-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7861.76,
#         'DistanceFromCall': 7409.53,
#         'PresentableDistance': '4.6 miles away',
#         'StopsFromCall': 31}},
#       'StopPointName': 'NOSTRAND AV/CLARENDON RD',
#       'StopPointRef': 'MTA_303476'},
#      {'ExpectedArrivalTime': '2018-09-26T00:10:12.314-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8167.9,
#         'DistanceFromCall': 7715.67,
#         'PresentableDistance': '4.8 miles away',
#         'StopsFromCall': 32}},
#       'StopPointName': 'NOSTRAND AV/NEWKIRK AV',
#       'StopPointRef': 'MTA_303477'},
#      {'ExpectedArrivalTime': '2018-09-26T00:11:09.676-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8375.09,
#         'DistanceFromCall': 7922.86,
#         'PresentableDistance': '4.9 miles away',
#         'StopsFromCall': 33}},
#       'StopPointName': 'NOSTRAND AV/FOSTER AV',
#       'StopPointRef': 'MTA_308360'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:05.684-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8631.78,
#         'DistanceFromCall': 8179.55,
#         'PresentableDistance': '5.1 miles away',
#         'StopsFromCall': 34}},
#       'StopPointName': 'NOSTRAND AV/FARRAGUT RD',
#       'StopPointRef': 'MTA_303479'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:42.084-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8836.56,
#         'DistanceFromCall': 8384.34,
#         'PresentableDistance': '5.2 miles away',
#         'StopsFromCall': 35}},
#       'StopPointName': 'NOSTRAND AV/GLENWOOD RD',
#       'StopPointRef': 'MTA_303480'},
#      {'ExpectedArrivalTime': '2018-09-26T00:14:58.171-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9105.35,
#         'DistanceFromCall': 8653.13,
#         'PresentableDistance': '5.4 miles away',
#         'StopsFromCall': 36}},
#       'StopPointName': 'NOSTRAND AV/AV H',
#       'StopPointRef': 'MTA_306906'},
#      {'ExpectedArrivalTime': '2018-09-26T00:15:53.973-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9424.38,
#         'DistanceFromCall': 8972.15,
#         'PresentableDistance': '5.6 miles away',
#         'StopsFromCall': 37}},
#       'StopPointName': 'NOSTRAND AV/AV I',
#       'StopPointRef': 'MTA_303482'},
#      {'ExpectedArrivalTime': '2018-09-26T00:16:47.959-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9692.76,
#         'DistanceFromCall': 9240.53,
#         'PresentableDistance': '5.7 miles away',
#         'StopsFromCall': 38}},
#       'StopPointName': 'NOSTRAND AV/AV J',
#       'StopPointRef': 'MTA_303483'},
#      {'ExpectedArrivalTime': '2018-09-26T00:17:25.261-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9937.85,
#         'DistanceFromCall': 9485.62,
#         'PresentableDistance': '5.9 miles away',
#         'StopsFromCall': 39}},
#       'StopPointName': 'NOSTRAND AV/AV K',
#       'StopPointRef': 'MTA_303484'},
#      {'ExpectedArrivalTime': '2018-09-26T00:18:09.118-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10227.04,
#         'DistanceFromCall': 9774.81,
#         'PresentableDistance': '6.1 miles away',
#         'StopsFromCall': 40}},
#       'StopPointName': 'NOSTRAND AV/AV L',
#       'StopPointRef': 'MTA_308057'},
#      {'ExpectedArrivalTime': '2018-09-26T00:18:54.720-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10501.14,
#         'DistanceFromCall': 10048.91,
#         'PresentableDistance': '6.2 miles away',
#         'StopsFromCall': 41}},
#       'StopPointName': 'NOSTRAND AV/AV M',
#       'StopPointRef': 'MTA_303486'},
#      {'ExpectedArrivalTime': '2018-09-26T00:19:33.064-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10764.38,
#         'DistanceFromCall': 10312.15,
#         'PresentableDistance': '6.4 miles away',
#         'StopsFromCall': 42}},
#       'StopPointName': 'NOSTRAND AV/AV N',
#       'StopPointRef': 'MTA_303487'},
#      {'ExpectedArrivalTime': '2018-09-26T00:19:46.401-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10840.47,
#         'DistanceFromCall': 10388.24,
#         'PresentableDistance': '6.5 miles away',
#         'StopsFromCall': 43}},
#       'StopPointName': 'NOSTRAND AV/KINGS HY',
#       'StopPointRef': 'MTA_303488'},
#      {'ExpectedArrivalTime': '2018-09-26T00:20:57.831-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11354.28,
#         'DistanceFromCall': 10902.06,
#         'PresentableDistance': '6.8 miles away',
#         'StopsFromCall': 44}},
#       'StopPointName': 'NOSTRAND AV/AV P',
#       'StopPointRef': 'MTA_303490'},
#      {'ExpectedArrivalTime': '2018-09-26T00:21:53.863-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11597.8,
#         'DistanceFromCall': 11145.57,
#         'PresentableDistance': '6.9 miles away',
#         'StopsFromCall': 45}},
#       'StopPointName': 'NOSTRAND AV/QUENTIN RD',
#       'StopPointRef': 'MTA_303491'},
#      {'ExpectedArrivalTime': '2018-09-26T00:22:35.496-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11878.59,
#         'DistanceFromCall': 11426.36,
#         'PresentableDistance': '7.1 miles away',
#         'StopsFromCall': 46}},
#       'StopPointName': 'NOSTRAND AV/AV R',
#       'StopPointRef': 'MTA_303492'},
#      {'ExpectedArrivalTime': '2018-09-26T00:23:10.518-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12128.44,
# ...
#       'StopPointRef': 'MTA_303457'},
#      {'ExpectedArrivalTime': '2018-09-25T23:39:02.884-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4339.72,
#         'DistanceFromCall': 531.96,
#         'PresentableDistance': '2 stops away',
#         'StopsFromCall': 2}},
#       'StopPointName': 'NOSTRAND AV/PROSPECT PL',
#       'StopPointRef': 'MTA_308524'},
#      {'ExpectedArrivalTime': '2018-09-25T23:40:55.294-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4734.56,
#         'DistanceFromCall': 926.8,
#         'PresentableDistance': '0.6 miles away',
#         'StopsFromCall': 3}},
#       'StopPointName': 'NOSTRAND AV/ST JOHNS PL',
#       'StopPointRef': 'MTA_303459'},
#      {'ExpectedArrivalTime': '2018-09-25T23:42:18.088-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 4911.09,
#         'DistanceFromCall': 1103.33,
#         'PresentableDistance': '0.7 miles away',
#         'StopsFromCall': 4}},
#       'StopPointName': 'NOSTRAND AV/EASTERN PY',
#       'StopPointRef': 'MTA_303460'},
#      {'ExpectedArrivalTime': '2018-09-25T23:43:48.288-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5181.08,
#         'DistanceFromCall': 1373.32,
#         'PresentableDistance': '0.9 miles away',
#         'StopsFromCall': 5}},
#       'StopPointName': 'NOSTRAND AV/CARROLL ST',
#       'StopPointRef': 'MTA_303461'},
#      {'ExpectedArrivalTime': '2018-09-25T23:44:19.212-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5337.97,
#         'DistanceFromCall': 1530.21,
#         'PresentableDistance': '1.0 miles away',
#         'StopsFromCall': 6}},
#       'StopPointName': 'NOSTRAND AV/MONTGOMERY ST',
#       'StopPointRef': 'MTA_308443'},
#      {'ExpectedArrivalTime': '2018-09-25T23:45:11.895-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5558.64,
#         'DistanceFromCall': 1750.88,
#         'PresentableDistance': '1.1 miles away',
#         'StopsFromCall': 7}},
#       'StopPointName': 'NOSTRAND AV/EMPIRE BL',
#       'StopPointRef': 'MTA_303463'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:11.095-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5725.22,
#         'DistanceFromCall': 1917.46,
#         'PresentableDistance': '1.2 miles away',
#         'StopsFromCall': 8}},
#       'StopPointName': 'NOSTRAND AV/LEFFERTS AV',
#       'StopPointRef': 'MTA_303464'},
#      {'ExpectedArrivalTime': '2018-09-25T23:46:45.095-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 5888.23,
#         'DistanceFromCall': 2080.47,
#         'PresentableDistance': '1.3 miles away',
#         'StopsFromCall': 9}},
#       'StopPointName': 'NOSTRAND AV/MAPLE ST',
#       'StopPointRef': 'MTA_303465'},
#      {'ExpectedArrivalTime': '2018-09-25T23:47:21.766-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6051.49,
#         'DistanceFromCall': 2243.73,
#         'PresentableDistance': '1.4 miles away',
#         'StopsFromCall': 10}},
#       'StopPointName': 'NOSTRAND AV/RUTLAND RD',
#       'StopPointRef': 'MTA_303466'},
#      {'ExpectedArrivalTime': '2018-09-25T23:48:00.268-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6225.72,
#         'DistanceFromCall': 2417.97,
#         'PresentableDistance': '1.5 miles away',
#         'StopsFromCall': 11}},
#       'StopPointName': 'NOSTRAND AV/HAWTHORNE ST',
#       'StopPointRef': 'MTA_303467'},
#      {'ExpectedArrivalTime': '2018-09-25T23:49:20.479-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6502.78,
#         'DistanceFromCall': 2695.02,
#         'PresentableDistance': '1.7 miles away',
#         'StopsFromCall': 12}},
#       'StopPointName': 'NOSTRAND AV/CLARKSON AV',
#       'StopPointRef': 'MTA_303469'},
#      {'ExpectedArrivalTime': '2018-09-25T23:50:52.498-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 6808.04,
#         'DistanceFromCall': 3000.28,
#         'PresentableDistance': '1.9 miles away',
#         'StopsFromCall': 13}},
#       'StopPointName': 'NOSTRAND AV/LINDEN BL',
#       'StopPointRef': 'MTA_303471'},
#      {'ExpectedArrivalTime': '2018-09-25T23:52:00.170-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7021.44,
#         'DistanceFromCall': 3213.69,
#         'PresentableDistance': '2.0 miles away',
#         'StopsFromCall': 14}},
#       'StopPointName': 'NOSTRAND AV/CHURCH AV',
#       'StopPointRef': 'MTA_307737'},
#      {'ExpectedArrivalTime': '2018-09-25T23:53:07.121-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7216.96,
#         'DistanceFromCall': 3409.2,
#         'PresentableDistance': '2.1 miles away',
#         'StopsFromCall': 15}},
#       'StopPointName': 'NOSTRAND AV/SNYDER AV',
#       'StopPointRef': 'MTA_303473'},
#      {'ExpectedArrivalTime': '2018-09-25T23:53:47.938-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7445.74,
#         'DistanceFromCall': 3637.98,
#         'PresentableDistance': '2.3 miles away',
#         'StopsFromCall': 16}},
#       'StopPointName': 'NOSTRAND AV/TILDEN AV',
#       'StopPointRef': 'MTA_303474'},
#      {'ExpectedArrivalTime': '2018-09-25T23:54:44.360-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7642.29,
#         'DistanceFromCall': 3834.53,
#         'PresentableDistance': '2.4 miles away',
#         'StopsFromCall': 17}},
#       'StopPointName': 'NOSTRAND AV/BEVERLY RD',
#       'StopPointRef': 'MTA_303475'},
#      {'ExpectedArrivalTime': '2018-09-25T23:55:40.602-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 7861.76,
#         'DistanceFromCall': 4054.0,
#         'PresentableDistance': '2.5 miles away',
#         'StopsFromCall': 18}},
#       'StopPointName': 'NOSTRAND AV/CLARENDON RD',
#       'StopPointRef': 'MTA_303476'},
#      {'ExpectedArrivalTime': '2018-09-25T23:56:53.048-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8167.9,
#         'DistanceFromCall': 4360.14,
#         'PresentableDistance': '2.7 miles away',
#         'StopsFromCall': 19}},
#       'StopPointName': 'NOSTRAND AV/NEWKIRK AV',
#       'StopPointRef': 'MTA_303477'},
#      {'ExpectedArrivalTime': '2018-09-25T23:57:53.010-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8375.09,
#         'DistanceFromCall': 4567.33,
#         'PresentableDistance': '2.8 miles away',
#         'StopsFromCall': 20}},
#       'StopPointName': 'NOSTRAND AV/FOSTER AV',
#       'StopPointRef': 'MTA_308360'},
#      {'ExpectedArrivalTime': '2018-09-25T23:58:52.218-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8631.78,
#         'DistanceFromCall': 4824.02,
#         'PresentableDistance': '3.0 miles away',
#         'StopsFromCall': 21}},
#       'StopPointName': 'NOSTRAND AV/FARRAGUT RD',
#       'StopPointRef': 'MTA_303479'},
#      {'ExpectedArrivalTime': '2018-09-25T23:59:31.418-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 8836.56,
#         'DistanceFromCall': 5028.8,
#         'PresentableDistance': '3.1 miles away',
#         'StopsFromCall': 22}},
#       'StopPointName': 'NOSTRAND AV/GLENWOOD RD',
#       'StopPointRef': 'MTA_303480'},
#      {'ExpectedArrivalTime': '2018-09-26T00:01:50.905-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9105.35,
#         'DistanceFromCall': 5297.59,
#         'PresentableDistance': '3.3 miles away',
#         'StopsFromCall': 23}},
#       'StopPointName': 'NOSTRAND AV/AV H',
#       'StopPointRef': 'MTA_306906'},
#      {'ExpectedArrivalTime': '2018-09-26T00:02:46.707-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9424.38,
#         'DistanceFromCall': 5616.62,
#         'PresentableDistance': '3.5 miles away',
#         'StopsFromCall': 24}},
#       'StopPointName': 'NOSTRAND AV/AV I',
#       'StopPointRef': 'MTA_303482'},
#      {'ExpectedArrivalTime': '2018-09-26T00:03:40.693-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9692.76,
#         'DistanceFromCall': 5885.0,
#         'PresentableDistance': '3.7 miles away',
#         'StopsFromCall': 25}},
#       'StopPointName': 'NOSTRAND AV/AV J',
#       'StopPointRef': 'MTA_303483'},
#      {'ExpectedArrivalTime': '2018-09-26T00:04:17.995-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 9937.85,
#         'DistanceFromCall': 6130.09,
#         'PresentableDistance': '3.8 miles away',
#         'StopsFromCall': 26}},
#       'StopPointName': 'NOSTRAND AV/AV K',
#       'StopPointRef': 'MTA_303484'},
#      {'ExpectedArrivalTime': '2018-09-26T00:05:01.852-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10227.04,
#         'DistanceFromCall': 6419.28,
#         'PresentableDistance': '4.0 miles away',
#         'StopsFromCall': 27}},
#       'StopPointName': 'NOSTRAND AV/AV L',
#       'StopPointRef': 'MTA_308057'},
#      {'ExpectedArrivalTime': '2018-09-26T00:05:47.454-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10501.14,
#         'DistanceFromCall': 6693.38,
#         'PresentableDistance': '4.2 miles away',
#         'StopsFromCall': 28}},
#       'StopPointName': 'NOSTRAND AV/AV M',
#       'StopPointRef': 'MTA_303486'},
#      {'ExpectedArrivalTime': '2018-09-26T00:06:25.798-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10764.38,
#         'DistanceFromCall': 6956.62,
#         'PresentableDistance': '4.3 miles away',
#         'StopsFromCall': 29}},
#       'StopPointName': 'NOSTRAND AV/AV N',
#       'StopPointRef': 'MTA_303487'},
#      {'ExpectedArrivalTime': '2018-09-26T00:06:39.135-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 10840.47,
#         'DistanceFromCall': 7032.71,
#         'PresentableDistance': '4.4 miles away',
#         'StopsFromCall': 30}},
#       'StopPointName': 'NOSTRAND AV/KINGS HY',
#       'StopPointRef': 'MTA_303488'},
#      {'ExpectedArrivalTime': '2018-09-26T00:07:50.565-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11354.28,
#         'DistanceFromCall': 7546.53,
#         'PresentableDistance': '4.7 miles away',
#         'StopsFromCall': 31}},
#       'StopPointName': 'NOSTRAND AV/AV P',
#       'StopPointRef': 'MTA_303490'},
#      {'ExpectedArrivalTime': '2018-09-26T00:08:46.597-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11597.8,
#         'DistanceFromCall': 7790.04,
#         'PresentableDistance': '4.8 miles away',
#         'StopsFromCall': 32}},
#       'StopPointName': 'NOSTRAND AV/QUENTIN RD',
#       'StopPointRef': 'MTA_303491'},
#      {'ExpectedArrivalTime': '2018-09-26T00:09:28.230-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 11878.59,
#         'DistanceFromCall': 8070.83,
#         'PresentableDistance': '5.0 miles away',
#         'StopsFromCall': 33}},
#       'StopPointName': 'NOSTRAND AV/AV R',
#       'StopPointRef': 'MTA_303492'},
#      {'ExpectedArrivalTime': '2018-09-26T00:10:03.252-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12128.44,
#         'DistanceFromCall': 8320.69,
#         'PresentableDistance': '5.2 miles away',
#         'StopsFromCall': 34}},
#       'StopPointName': 'NOSTRAND AV/AV S',
#       'StopPointRef': 'MTA_303493'},
#      {'ExpectedArrivalTime': '2018-09-26T00:10:43.279-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12399.81,
#         'DistanceFromCall': 8592.05,
#         'PresentableDistance': '5.3 miles away',
#         'StopsFromCall': 35}},
#       'StopPointName': 'NOSTRAND AV/AV T',
#       'StopPointRef': 'MTA_303494'},
#      {'ExpectedArrivalTime': '2018-09-26T00:11:15.079-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12601.31,
#         'DistanceFromCall': 8793.55,
#         'PresentableDistance': '5.5 miles away',
#         'StopsFromCall': 36}},
#       'StopPointName': 'NOSTRAND AV/AV U',
#       'StopPointRef': 'MTA_303495'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:11.172-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 12886.2,
#         'DistanceFromCall': 9078.44,
#         'PresentableDistance': '5.6 miles away',
#         'StopsFromCall': 37}},
#       'StopPointName': 'NOSTRAND AV/AV V',
#       'StopPointRef': 'MTA_302830'},
#      {'ExpectedArrivalTime': '2018-09-26T00:12:47.202-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13108.93,
#         'DistanceFromCall': 9301.17,
#         'PresentableDistance': '5.8 miles away',
#         'StopsFromCall': 38}},
#       'StopPointName': 'NOSTRAND AV/AV W',
#       'StopPointRef': 'MTA_302831'},
#      {'ExpectedArrivalTime': '2018-09-26T00:13:28.414-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13351.75,
#         'DistanceFromCall': 9543.99,
#         'PresentableDistance': '5.9 miles away',
#         'StopsFromCall': 39}},
#       'StopPointName': 'NOSTRAND AV/AV X',
#       'StopPointRef': 'MTA_302832'},
#      {'ExpectedArrivalTime': '2018-09-26T00:14:18.442-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13633.66,
#         'DistanceFromCall': 9825.9,
#         'PresentableDistance': '6.1 miles away',
#         'StopsFromCall': 40}},
#       'StopPointName': 'NOSTRAND AV/AV Y',
#       'StopPointRef': 'MTA_302833'},
#      {'ExpectedArrivalTime': '2018-09-26T00:14:43.854-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 13823.94,
#         'DistanceFromCall': 10016.18,
#         'PresentableDistance': '6.2 miles away',
#         'StopsFromCall': 41}},
#       'StopPointName': 'NOSTRAND AV/AV Z',
#       'StopPointRef': 'MTA_302834'},
#      {'ExpectedArrivalTime': '2018-09-26T00:15:20.844-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14123.74,
#         'DistanceFromCall': 10315.98,
#         'PresentableDistance': '6.4 miles away',
#         'StopsFromCall': 42}},
#       'StopPointName': 'NOSTRAND AV/VOORHIES AV',
#       'StopPointRef': 'MTA_303502'},
#      {'ExpectedArrivalTime': '2018-09-26T00:15:45.707-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14328.67,
#         'DistanceFromCall': 10520.91,
#         'PresentableDistance': '6.5 miles away',
#         'StopsFromCall': 43}},
#       'StopPointName': 'SHORE PKY/NOSTRAND AV',
#       'StopPointRef': 'MTA_306898'},
#      {'ExpectedArrivalTime': '2018-09-26T00:16:03.282-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14485.79,
#         'DistanceFromCall': 10678.03,
#         'PresentableDistance': '6.6 miles away',
#         'StopsFromCall': 44}},
#       'StopPointName': 'SHORE PKY/BROWN ST',
#       'StopPointRef': 'MTA_306899'},
#      {'ExpectedArrivalTime': '2018-09-26T00:16:30.565-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14746.45,
#         'DistanceFromCall': 10938.69,
#         'PresentableDistance': '6.8 miles away',
#         'StopsFromCall': 45}},
#       'StopPointName': 'SHORE PKY/COYLE ST',
#       'StopPointRef': 'MTA_307669'},
#      {'ExpectedArrivalTime': '2018-09-26T00:16:59.283-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 14919.45,
#         'DistanceFromCall': 11111.69,
#         'PresentableDistance': '6.9 miles away',
#         'StopsFromCall': 46}},
#       'StopPointName': 'SHORE PKY/BRIGHAM ST',
#       'StopPointRef': 'MTA_307045'},
#      {'ExpectedArrivalTime': '2018-09-26T00:17:37.983-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15013.12,
#         'DistanceFromCall': 11205.36,
#         'PresentableDistance': '7.0 miles away',
#         'StopsFromCall': 47}},
#       'StopPointName': 'KNAPP ST/SHORE PKY',
#       'StopPointRef': 'MTA_901011'},
#      {'ExpectedArrivalTime': '2018-09-26T00:19:38.316-04:00',
#       'Extensions': {'Distances': {'CallDistanceAlongRoute': 15714.75,
#         'DistanceFromCall': 11906.99,
#         'PresentableDistance': '7.4 miles away',
#         'StopsFromCall': 48}},
#       'StopPointName': 'EMMONS AV/NOSTRAND AV',
#       'StopPointRef': 'MTA_901009'}]},
#    'OperatorRef': 'MTA NYCT',
#    'OriginRef': 'MTA_307915',
#    'ProgressRate': 'normalProgress',
#    'PublishedLineName': 'B44',
#    'SituationRef': [],
#    'VehicleLocation': {'Latitude': 40.679182, 'Longitude': -73.949627},
#    'VehicleRef': 'MTA NYCT_4628'},
#   'RecordedAtTime': '2018-09-25T23:35:29.000-04:00'}]

# %%
path=data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
print ('Bus Line:',this_bus)
print ('Number of Active Busses:', len(path))
bus_number=0
for i in path:
    print('Bus',bus_number, 'is at','Latitude:',i['MonitoredVehicleJourney']['VehicleLocation']['Latitude'],'and Longitude:',i['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])
    bus_number+=1
# Out:
# Bus Line: B44
# Number of Active Busses: 9
# Bus 0 is at Latitude: 40.663916 and Longitude: -73.948082
# Bus 1 is at Latitude: 40.709361 and Longitude: -73.95966
# Bus 2 is at Latitude: 40.61001 and Longitude: -73.943673
# Bus 3 is at Latitude: 40.706979 and Longitude: -73.961343
# Bus 4 is at Latitude: 40.709557 and Longitude: -73.960216
# Bus 5 is at Latitude: 40.610339 and Longitude: -73.943731
# Bus 6 is at Latitude: 40.648102 and Longitude: -73.949295
# Bus 7 is at Latitude: 40.584035 and Longitude: -73.936261
# Bus 8 is at Latitude: 40.679182 and Longitude: -73.949627

# %%
#need to loop through array at the end 
#columns: latitude, longitude, stop name, stop status
